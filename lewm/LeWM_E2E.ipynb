# %% [markdown]
# ### Installation

# %%
from google.colab import userdata
import os

# 1. Install MuJoCo & IK solver
# !pip install -q mujoco mink "qpsolvers[osqp]"
# !pip install -q "rerun-sdk[all]==0.28.2" "imageio[ffmpeg]"
# !pip install -q "transformers<5.0.0" "lerobot==0.4.3"
# !pip install -q hydra-core lightning omegaconf h5py hdf5plugin
# !pip install -q stable-pretraining stable-worldmodel torchcodec

# 2. Authenticate and Clone Private Repo
token = userdata.get("GITHUB_TOKEN")
github_url = f"https://{token}@github.com/vedpatwardhan/le-probe.git"
# !git clone --recursive $github_url

print("✅ MuJoCo Environment Initialized.")
exit()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 125.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.5/869.5 kB 66.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.2/32.2 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %% [markdown]
# ### Rerun Script

# %% [markdown]
# ### Run

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !hf auth login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `robot` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# ...

# %%
# %cd /content/le-probe
# %env PYTHONPATH=/env/python:/content/le-probe/research:/content/le-probe/le_wm
# Out:
# /content/le-probe
# env: PYTHONPATH=/env/python:/content/le-probe/research:/content/le-probe/le_wm

# %%
# !cp /content/drive/MyDrive/Masters_Project/lewm_grasp_baseline/run1/outputs/gr1_grasp_v3/checkpoints/gr1-epoch=99-step=004400.ckpt .
# !cp /content/drive/MyDrive/Masters_Project/lewm_grasp_baseline/run1/gr1_reward_tuned_v2.ckpt .
# !cp /content/drive/MyDrive/Masters_Project/lewm_grasp_baseline/run1/goal_gallery.pth .

# %%
# !python lewm_server.py --model "gr1-epoch=99-step=004400.ckpt" --gallery goal_gallery.pth
# !python lewm_server.py --model gr1_reward_tuned_v2.ckpt --gallery goal_gallery.pth
# Out:
# 2026-04-26 14:52:29.036526: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777215149.069688    7290 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777215149.079960    7290 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777215149.105870    7290 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !cd research && python harvest_goals.py --model ../gr1-epoch=99-step=004400.ckpt
# Out:
# Streaming output truncated to the last 5000 lines.
# videos/observation.images.world_top/chun(…):   0% 0.00/133k [00:00<?, ?B/s]
# videos/observation.images.world_top/chun(…):   0% 0.00/111k [00:00<?, ?B/s]
#
#
#
#
#
# videos/observation.images.world_top/chun(…):   0% 0.00/134k [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/observation.images.world_top/chun(…):   0% 0.00/125k [00:00<?, ?B/s]
#
# videos/observation.images.world_top/chun(…):   0% 0.00/112k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# videos/observation.images.world_top/chun(…): 100% 135k/135k [00:01<00:00, 131kB/s]
#
#
#
#
# videos/observation.images.world_top/chun(…):   0% 0.00/138k [00:00<?, ?B/s]
#
#
# videos/observation.images.world_top/chun(…):   0% 0.00/120k [00:00<?, ?B/s]
#
#
#
#
# videos/observation.images.world_top/chun(…): 100% 133k/133k [00:00<00:00, 318kB/s]
#
# videos/observation.images.world_top/chun(…): 100% 111k/111k [00:00<00:00, 182kB/s]
#
#
#
#
#
#
# ...

# %%
# !cp research/goal_gallery.pth /content/drive/MyDrive/Masters_Project/lewm_grasp_baseline/run1

# %%
# !cd research && python diagnose_mpc.py --model ../gr1-epoch=99-step=004400.ckpt --gallery ../goal_gallery.pth
# Out:
# 2026-04-24 12:10:19.989758: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777032620.009635   13356 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777032620.015758   13356 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777032620.031543   13356 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !git stash
# Out:
# Saved working directory and index state WIP on main: 1e46a77 added the init_var to the mock config

# %%
# !ls
# Out:
#  debug_simulation.py		  le_wm		       simulation_lewm.py
#  goal_gallery.pth		  lewm_server.py       simulation_replay.py
#  gr00t_server.py		  __pycache__	       simulation_teleop.py
#  gr1_config.py			  README.md	       simulation_vla.py
# 'gr1-epoch=99-step=004400.ckpt'   requirements.txt     teleop_ui.py
#  gr1_joint_order.txt		  research	       tests
#  gr1_protocol.py		  sim_assets
#  ik_joints.txt			  simulation_base.py

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 312 bytes | 312.00 KiB/s, done.
# From https://github.com/vedpatwardhan/le-probe
#  * branch            main       -> FETCH_HEAD
#    5b69a9a..c3565b5  main       -> origin/main
# Updating 5b69a9a..c3565b5
# Fast-forward
#  lewm_server.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
